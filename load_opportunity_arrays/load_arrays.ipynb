# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr_1 = np.load("op_dist_counts_bl_1.npy")
plt.plot(arr_1, range(len(arr_1)))

# %%
arr_10 = np.load("op_dist_counts_bl_10.npy")
plt.plot(arr_10, range(len(arr_10)))

# %%
arr_50 = np.load("op_dist_counts_bl_50.npy")
plt.plot(arr_50, range(len(arr_50)))

# %%
arr_100 = np.load("op_dist_counts_bl_100.npy")
plt.plot(arr_100, range(len(arr_100)))

# %%
arr_1000 = np.load("op_dist_counts_bl_1000.npy")
plt.plot(arr_1000, range(len(arr_1000)))
